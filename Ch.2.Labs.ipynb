# %% [markdown]
# # 2. Data & Features

# %%
#############################################################################################

# %% [markdown]
# ## 2. Lab #2

# %%
import pandas as pd

# %%
# 2.1.a. Load up Module2/Datasets/tutorial.csv
mydf = pd.read_csv('Datasets/tutorial.csv')
mydf.head()
# Out:
#        col0      col1      col2      col3
# 0 -0.722876 -1.330682  1.309208  0.232378
# 1  1.160396 -0.730879  0.677368  1.044722
# 2 -1.062870 -0.503704 -0.238536 -1.417937
# 3  0.437078  0.362640 -0.111228 -1.649853

# %%
# 2.1.b. Print the entire dataframe, using print df
print mydf
# Out:
#        col0      col1      col2      col3
# 0 -0.722876 -1.330682  1.309208  0.232378
# 1  1.160396 -0.730879  0.677368  1.044722
# 2 -1.062870 -0.503704 -0.238536 -1.417937
# 3  0.437078  0.362640 -0.111228 -1.649853

# %%
# 2.1.c. Use the .describe() method on the dataset
mydf.describe()
# Out:
#            col0      col1      col2      col3
# count  4.000000  4.000000  4.000000  4.000000
# mean  -0.047068 -0.550656  0.409203 -0.447672
# std    1.029715  0.701720  0.723956  1.300815
# min   -1.062870 -1.330682 -0.238536 -1.649853
# 25%   -0.807875 -0.880830 -0.143055 -1.475916
# 50%   -0.142899 -0.617291  0.283070 -0.592780
# 75%    0.617907 -0.287118  0.835328  0.435464
# max    1.160396  0.362640  1.309208  1.044722

# %%
# 2.1.d.Slice the dataset using [2:4, 'col3']
print mydf.loc[2:4, ['col3']]
# Out:
#        col3
# 2 -1.417937
# 3 -1.649853

# %%
print mydf.loc[2:4, 'col3']
# Out:
# 2   -1.417937
# 3   -1.649853
# Name: col3, dtype: float64

# %%
#############################################################################################

# %% [markdown]
# ## 2. Lab #3

# %%
servo = pd.read_csv('./Datasets/servo.data',  
            names = ['motor', 'screw', 'pgain', 'vgain', 'class']) # You can add header row with 'names'

# %%
# (Same effect.) You can use .columns = ['A', 'B', 'C'] 
# 'header=None' should be included NOT to overwrite the first row
servo = pd.read_csv('./Datasets/servo.data', header=None) 
servo.columns = ['motor', 'screw', 'pgain', 'vgain', 'class']

# %%
servo.head()
# Out:
#   motor screw  pgain  vgain     class
# 0     E     E      5      4  0.281251
# 1     B     D      6      5  0.506252
# 2     D     D      4      3  0.356251
# 3     B     A      3      2  5.500033
# 4     D     B      6      5  0.356251

# %%
servo.describe()
# Out:
#             pgain       vgain       class
# count  167.000000  167.000000  167.000000
# mean     4.155689    2.538922    1.389708
# std      1.017770    1.369850    1.559635
# min      3.000000    1.000000    0.131250
# 25%      3.000000    1.000000    0.503126
# 50%      4.000000    2.000000    0.731254
# 75%      5.000000    4.000000    1.259369
# max      6.000000    5.000000    7.100108

# %%
servo.count()
# Out:
# motor    167
# screw    167
# pgain    167
# vgain    167
# class    167
# dtype: int64

# %%
servo.columns
# Out:
# Index([u'E', u'E.1', u'5', u'4', u' 0.28125095'], dtype='object')

# %%
# 3.1. How many samples in this dataset have a vgain feature value equal to 5?
# My first trial. We can simply count the elements with len() or describe()
(servo[ servo['vgain'] == 5 ]).count()
# Out:
# motor    22
# screw    22
# pgain    22
# vgain    22
# class    22
# dtype: int64

# %%
# 3.2. How many samples in this dataset contain the value E for both motor and screw features?
# My first trial. We can simply count the elements with len() or describe()
(servo[ (servo['motor'] == 'E') & (servo['screw'] == 'E')]).count()
# Out:
# motor    6
# screw    6
# pgain    6
# vgain    6
# class    6
# dtype: int64

# %%
# 3.3. What is the mean vgain value of those samples that have a pgain feature value equal to 4?
(servo[ servo['pgain'] == 4 ]).describe()
# Out:
#        pgain      vgain      class
# count     66  66.000000  66.000000
# mean       4   2.060606   0.673298
# std        0   0.820484   0.314105
# min        4   1.000000   0.131250
# 25%        4   1.000000   0.365627
# 50%        4   2.000000   0.712504
# 75%        4   3.000000   0.956256
# max        4   3.000000   1.218740

# %% [markdown]
# #### *** Lab. #3. 정답 ***
# Before anything else, take a look at the names parameter of read_csv(). It's quite useful.
#
# \# Lab 3.a. For the first problem, you need to filter by the vgain column, e.g.: <b> df = df[df.vgain==5] </b>. Then you can simply count the number of results, or use <b>.describe()</b>, or <b>len()</b>.

# %%
# Lab 3.a. You can simply count the number of results, or use .describe(), or len()
servo3a = servo[ servo.vgain==5 ] 
len(servo3a)
# Out:
# 22

# %% [markdown]
# \# Lab 3.b. The second problem is similar, but you have to make use of two filters. You can either do this successively, or combine them and use the bitwise <b>df = df[ (df.motor=='E') & (df.screw=='E') ]</b> to concatenate the separate filters. It's important to encapsulate the two conditionals within (brackets).

# %%
servo3b = servo[ (servo.motor == 'E') & (servo.screw == 'E')]
len(servo3b)
# Out:
# 6

# %% [markdown]
# \# Lab 3.c. For the last problem, you must first filter by pgain, then you can use either <b>.describe()</b>, or <b>.vgain.mean()</b> to find out the mean value of vgain.

# %%
servo3c = servo[ servo.pgain == 4 ]
print servo3c.describe()
print
print servo3c.vgain.mean()
# Out:
#        pgain      vgain      class
# count     66  66.000000  66.000000
# mean       4   2.060606   0.673298
# std        0   0.820484   0.314105
# min        4   1.000000   0.131250
# 25%        4   1.000000   0.365627
# 50%        4   2.000000   0.712504
# 75%        4   3.000000   0.956256
# max        4   3.000000   1.218740
#
# 2.06060606061

# %%
#############################################################################################

# %% [markdown]
# ## 2. Lab #4
#
# Navigate over to ESPN's website for NHL Historic Player Points Statistics, for the years 2014-2015. This page has a table on it with a few stats we're interested in obtaining. But it's a bit messy! Clean it up for us, using the appropriate commands to:

# %%
# 2.4.a. Load up the table on this page into a Pandas dataframe
import html5lib

# Only works with html5lib version 1.0b8
# pip install --upgrade html5lib==1.0b8
espntable = pd.read_html('http://espn.go.com/nhl/statistics/player/_/stat/points/sort/points/year/2015/seasontype/2', 
                         header = 1)

# %%
espntable
# Out:
# [     RK                  PLAYER  TEAM   GP    G    A  PTS  +/-  PIM  PTS/G  \
#  0     1          Jamie Benn, LW   DAL   82   35   52   87    1   64   1.06
#  1     2         John Tavares, C   NYI   82   38   48   86    5   46   1.05
#  2     3        Sidney Crosby, C   PIT   77   28   56   84    5   47   1.09
#  3     4       Alex Ovechkin, LW   WSH   81   53   28   81   10   58   1.00
#  4   NaN       Jakub Voracek, RW   PHI   82   22   59   81    1   78   0.99
#  5     6    Nicklas Backstrom, C   WSH   82   18   60   78    5   40   0.95
#  6     7         Tyler Seguin, C   DAL   71   37   40   77   -1   20   1.08
#  7     8         Jiri Hudler, LW   CGY   78   31   45   76   17   14   0.97
#  8   NaN        Daniel Sedin, LW   VAN   82   20   56   76    5   18   0.93
#  9    10  Vladimir Tarasenko, RW   STL   77   37   36   73   27   31   0.95
#  10  NaN                      PP    SH  NaN  NaN  NaN  NaN  NaN  NaN    NaN
# ...

# %%
espndf = espntable[0]
espndf.head()
# Out:
#     RK             PLAYER TEAM  GP   G   A PTS +/- PIM PTS/G  SOG   PCT GWG  \
# 0    1     Jamie Benn, LW  DAL  82  35  52  87   1  64  1.06  253  13.8   6
# 1    2    John Tavares, C  NYI  82  38  48  86   5  46  1.05  278  13.7   8
# 2    3   Sidney Crosby, C  PIT  77  28  56  84   5  47  1.09  237  11.8   3
# 3    4  Alex Ovechkin, LW  WSH  81  53  28  81  10  58  1.00  395  13.4  11
# 4  NaN  Jakub Voracek, RW  PHI  82  22  59  81   1  78  0.99  221  10.0   3
#
#   G.1 A.1 G.2 A.2
# 0  10  13   2   3
# 1  13  18   0   1
# 2  10  21   0   0
# 3  25   9   0   0
# 4  11  22   0   0

# %%
# Remove unnecessary rows having repeated header
espndf = espndf[ espndf['RK'] != 'RK' ]   
espndf.head()
# Out:
#     RK             PLAYER TEAM  GP   G   A PTS +/- PIM PTS/G  SOG   PCT GWG  \
# 0    1     Jamie Benn, LW  DAL  82  35  52  87   1  64  1.06  253  13.8   6
# 1    2    John Tavares, C  NYI  82  38  48  86   5  46  1.05  278  13.7   8
# 2    3   Sidney Crosby, C  PIT  77  28  56  84   5  47  1.09  237  11.8   3
# 3    4  Alex Ovechkin, LW  WSH  81  53  28  81  10  58  1.00  395  13.4  11
# 4  NaN  Jakub Voracek, RW  PHI  82  22  59  81   1  78  0.99  221  10.0   3
#
#   G.1 A.1 G.2 A.2
# 0  10  13   2   3
# 1  13  18   0   1
# 2  10  21   0   0
# 3  25   9   0   0
# 4  11  22   0   0

# %%
# 2.4.b. Rename the columns so that they match the column definitions on the website
'''
GP: Games Played
G: Goals
A: Assists
PTS: Points
+/-: Plus/Minus Rating
PIM: Penalty Minutes
PTS/G: Points Per Game
SOG: Shots on Goal
PCT: Shooting Percentage
GWG: Game-Winning Goals
G: Power-Play Goals
A: Power-Play Assists
G: Short-Handed Goals
A: Short-Handed Assists'''
espndf.columns = ['Rank','Player','Team','GamePlayed','Goals','Assists','Points', \
                     'Plus/Minus Rating','Penalty Minutes','Points Per Game', 'Shots on Goals',\
                     'Shooting Percentage','Game-Winning Assists', 'G.1', 'A.1','G.2','A.2' 
                    ]
espndf.head()
# Out:
#   Rank             Player Team GamePlayed Goals Assists Points  \
# 0    1     Jamie Benn, LW  DAL         82    35      52     87
# 1    2    John Tavares, C  NYI         82    38      48     86
# 2    3   Sidney Crosby, C  PIT         77    28      56     84
# 3    4  Alex Ovechkin, LW  WSH         81    53      28     81
# 4  NaN  Jakub Voracek, RW  PHI         82    22      59     81
#
#   Plus/Minus Rating Penalty Minutes Points Per Game Shots on Goals  \
# 0                 1              64            1.06            253
# 1                 5              46            1.05            278
# 2                 5              47            1.09            237
# 3                10              58            1.00            395
# 4                 1              78            0.99            221
#
#   Shooting Percentage Game-Winning Assists G.1 A.1 G.2 A.2
# 0                13.8                    6  10  13   2   3
# 1                13.7                    8  13  18   0   1
# ...

# %%
espndf.describe()
# Out:
#        Rank Player Team GamePlayed Goals Assists Points Plus/Minus Rating  \
# count    18     43   43         40    40      40     40                40
# unique   18     41   22         12    20      23     18                26
# top      21     PP   TB         82    28      40     64                 5
# freq      1      3    4         14     5       5      7                 5
#
#        Penalty Minutes Points Per Game Shots on Goals Shooting Percentage  \
# count               40              40             40                  40
# unique              28              27             39                  36
# top                 36            0.80            237                11.8
# freq                 4               4              2                   2
#
#        Game-Winning Assists G.1 A.1 G.2 A.2
# count                    40  40  40  40  40
# unique                   10  15  20   5   4
# top                       6   6  18   0   0
# freq                      8   9   4  31  32

# %%
espndf.count()
# Out:
# Rank                    18
# Player                  43
# Team                    43
# GamePlayed              40
# Goals                   40
# Assists                 40
# Points                  40
# Plus/Minus Rating       40
# Penalty Minutes         40
# Points Per Game         40
# Shots on Goals          40
# Shooting Percentage     40
# Game-Winning Assists    40
# G.1                     40
# A.1                     40
# G.2                     40
# A.2                     40
# dtype: int64

# %%
len(espndf)
# Out:
# 43

# %%
# 2.4.c. Get rid of any erroneous rows that has at least 4 NANs in them
espndf4c = espndf.dropna(thresh = 4) # <-- !!기억할 것 (threshold가 아님)!!!!
print len(espndf4c)
espndf4c.count()
# Out:
# 40
# Rank                    18
# Player                  40
# Team                    40
# GamePlayed              40
# Goals                   40
# Assists                 40
# Points                  40
# Plus/Minus Rating       40
# Penalty Minutes         40
# Points Per Game         40
# Shots on Goals          40
# Shooting Percentage     40
# Game-Winning Assists    40
# G.1                     40
# A.1                     40
# G.2                     40
# A.2                     40
# dtype: int64

# %%
# 2.4.d. Get rid of the RK column
espndf4d = espndf4c.copy() 
espndf4d = espndf4d.drop(['Rank'], axis=1)
espndf4d.head()
# Out:
#               Player Team GamePlayed Goals Assists Points Plus/Minus Rating  \
# 0     Jamie Benn, LW  DAL         82    35      52     87                 1
# 1    John Tavares, C  NYI         82    38      48     86                 5
# 2   Sidney Crosby, C  PIT         77    28      56     84                 5
# 3  Alex Ovechkin, LW  WSH         81    53      28     81                10
# 4  Jakub Voracek, RW  PHI         82    22      59     81                 1
#
#   Penalty Minutes Points Per Game Shots on Goals Shooting Percentage  \
# 0              64            1.06            253                13.8
# 1              46            1.05            278                13.7
# 2              47            1.09            237                11.8
# 3              58            1.00            395                13.4
# 4              78            0.99            221                10.0
#
#   Game-Winning Assists G.1 A.1 G.2 A.2
# 0                    6  10  13   2   3
# ...

# %%
espndf4d.loc[:15,:]  # The results contain some missing rows such as row #10-11 (Not a row with missing values)
# Out:
#                     Player Team GamePlayed Goals Assists Points  \
# 0           Jamie Benn, LW  DAL         82    35      52     87
# 1          John Tavares, C  NYI         82    38      48     86
# 2         Sidney Crosby, C  PIT         77    28      56     84
# 3        Alex Ovechkin, LW  WSH         81    53      28     81
# 4        Jakub Voracek, RW  PHI         82    22      59     81
# 5     Nicklas Backstrom, C  WSH         82    18      60     78
# 6          Tyler Seguin, C  DAL         71    37      40     77
# 7          Jiri Hudler, LW  CGY         78    31      45     76
# 8         Daniel Sedin, LW  VAN         82    20      56     76
# 9   Vladimir Tarasenko, RW  STL         77    37      36     73
# 12        Nick Foligno, LW  CBJ         79    31      42     73
# 13        Claude Giroux, C  PHI         81    25      48     73
# 14         Henrik Sedin, C  VAN         82    18      55     73
# 15       Steven Stamkos, C   TB         82    43      29     72
#
# ...

# %%
# Just for checking whether there is any missing value
espndf4d.isnull().sum()
# Out:
# Player                  0
# Team                    0
# GamePlayed              0
# Goals                   0
# Assists                 0
# Points                  0
# Plus/Minus Rating       0
# Penalty Minutes         0
# Points Per Game         0
# Shots on Goals          0
# Shooting Percentage     0
# Game-Winning Assists    0
# G.1                     0
# A.1                     0
# G.2                     0
# A.2                     0
# dtype: int64

# %%
espndf4d.count()
# Out:
# Player                  40
# Team                    40
# GamePlayed              40
# Goals                   40
# Assists                 40
# Points                  40
# Plus/Minus Rating       40
# Penalty Minutes         40
# Points Per Game         40
# Shots on Goals          40
# Shooting Percentage     40
# Game-Winning Assists    40
# G.1                     40
# A.1                     40
# G.2                     40
# A.2                     40
# dtype: int64

# %%
# 2.4.e. Ensure there are no nan "holes" in your index
espndf4e = espndf4d.reset_index(drop=True) 
espndf4e.loc[:15, :]
# Out:
#                     Player Team GamePlayed Goals Assists Points  \
# 0           Jamie Benn, LW  DAL         82    35      52     87
# 1          John Tavares, C  NYI         82    38      48     86
# 2         Sidney Crosby, C  PIT         77    28      56     84
# 3        Alex Ovechkin, LW  WSH         81    53      28     81
# 4        Jakub Voracek, RW  PHI         82    22      59     81
# 5     Nicklas Backstrom, C  WSH         82    18      60     78
# 6          Tyler Seguin, C  DAL         71    37      40     77
# 7          Jiri Hudler, LW  CGY         78    31      45     76
# 8         Daniel Sedin, LW  VAN         82    20      56     76
# 9   Vladimir Tarasenko, RW  STL         77    37      36     73
# 10        Nick Foligno, LW  CBJ         79    31      42     73
# 11        Claude Giroux, C  PHI         81    25      48     73
# 12         Henrik Sedin, C  VAN         82    18      55     73
# 13       Steven Stamkos, C   TB         82    43      29     72
# ...

# %%
# 2.4.f. Check the dtypes of all columns, and ensure those that should be numeric are numeric
espndf4e.dtypes # 요거 dtypes 단수가 아니라 복수임.
# Out:
# Player                  object
# Team                    object
# GamePlayed              object
# Goals                   object
# Assists                 object
# Points                  object
# Plus/Minus Rating       object
# Penalty Minutes         object
# Points Per Game         object
# Shots on Goals          object
# Shooting Percentage     object
# Game-Winning Assists    object
# G.1                     object
# A.1                     object
# G.2                     object
# A.2                     object
# dtype: object

# %%
espndf4e.describe()
# Out:
#                  Player Team GamePlayed Goals Assists Points  \
# count                40   40         40    40      40     40
# unique               40   21         12    20      23     18
# top     Ryan Getzlaf, C   TB         82    28      40     64
# freq                  1    4         14     5       5      7
#
#        Plus/Minus Rating Penalty Minutes Points Per Game Shots on Goals  \
# count                 40              40              40             40
# unique                26              28              27             39
# top                    5              36            0.80            237
# freq                   5               4               4              2
#
#        Shooting Percentage Game-Winning Assists G.1 A.1 G.2 A.2
# count                   40                   40  40  40  40  40
# unique                  36                   10  15  20   5   4
# top                   11.8                    6   6  18   0   0
# ...

# %%
# Question 2.4.1
len(espndf4e)
# Out:
# 40

# %%
# Question 2.4.2 
#len(espndf4e['Points Per Game'].unique())
len(espndf4e['Shooting Percentage'].unique()) # PCT를 'Points Per Game'으로 착각해서 27로 했음
# Out:
# 36

# %%
# 정답에 나온 표현.
espndf4f = espndf4e.drop_duplicates(subset=['Shooting Percentage']) 
len(espndf4f)
# Out:
# 36

# %%
# Question 2.4.3
int(espndf4e.loc[15, ['GamePlayed']]) + int(espndf4e.loc[16, ['GamePlayed']])
# Out:
# 164

# %% [markdown]
# #### *** Lab. #4. 정답 ***
# First load up your data using Pandas <b>.read_html()</b> method. This actually does not return a dataframe, but rather returns a list of dataframes, one per HTML table found on the page.
#
# The next thing you're going to want to do is use <b>.columns = []</b> to assign names to all of the columns. It's important that at this step, you know the difference between using <b>.columns</b> and <b>names=</b> within one of your dataset load methods!
#
# You're going to have to use a combination of <b>.drop(), .dropna()</b>, as well as some compound boolean selectors in order to clean up the table by getting rid of all the pesky rows. Review your previous assignments to see how this is done.
#
# Don't forget to reset your index, and also pass <b>Drop=True</b> when you do that, otherwise a copy of the original index column will be retained.
#
# Lastly, you need to check your table's data types. <b>.read_html()</b> always converts everything to a string, so you'll have to coerce your data to a numeric type using <b>pd.to_numeric()</b>. Read up on the documentation for that, and be sure to remember why that method is preferred to other methods, such as <b>astype()</b>.

# %%
#############################################################################################

# %% [markdown]
# ## 2. Lab #5
#
# Barry Becker extracted a reasonably clean subset of the 1994, [U.S. Census database](https://archive.ics.uci.edu/ml/datasets/Census+Income), with a goal of running predictions to determine whether a person makes over 50K a year. The dataset is hosted on the University of California, Irvine's Machine Learning Repository and includes features such as the person's age, occupation, and hours worked per week, etc.
#
# As clean as the data is, it still isn't quite ready for analysis by SciKit-Learn! Using what you've learned in this chapter, clean up the various columns by encode them properly using the best practices so that they're ready to be examined. We've included a modifies subset of the dataset at <b>Module2/Datasets/census.data</b> and also have some started code to get you going located at <b>Module2/assignment5.py</b>.
#
# Load up the dataset and set header label names to:
# ['education', 'age', 'capital-gain', 'race', 'capital-loss', 'hours-per-week', 'sex', 'classification']
#
# * [Pandas documentation - Missing_data](http://pandas.pydata.org/pandas-docs/stable/missing_data.html)

# %%
import numpy as np

# %%
# 2.5.1. 
# Ensure you use the right command to do this, as there is more than one command! 
# To verify you used the correct one, open the dataset in a text editor like SublimeText or Notepad, 
# and double check your df.head() to ensure the first values match up.

# if you don't want the first row to be a header (즉, 첫 row는 header가 아닌 data로)
# you should set 'header = None'
mydf5 = pd.read_csv('Module2/Datasets/census.data', header=None)  # <-- Remember !!!!!
del mydf5[0]
mydf5.head()
# Out:
#            1   2     3      4  5   6       7      8
# 0  Bachelors  39  2174  White  0  40    Male  <=50K
# 1  Bachelors  50     ?  White  0  13    Male  <=50K
# 2    HS-grad  38     ?  White  0  40    Male  <=50K
# 3       11th  53     ?  Black  0  40    Male  <=50K
# 4  Bachelors  28     0  Black  0  40  Female  <=50K

# %%
mydf5.columns = ['education', 'age', 'capital-gain', 'race', 'capital-loss', 'hours-per-week', 'sex', 'classification']
mydf5.head()
# Out:
#    education  age capital-gain   race  capital-loss  hours-per-week     sex  \
# 0  Bachelors   39         2174  White             0              40    Male
# 1  Bachelors   50            ?  White             0              13    Male
# 2    HS-grad   38            ?  White             0              40    Male
# 3       11th   53            ?  Black             0              40    Male
# 4  Bachelors   28            0  Black             0              40  Female
#
#   classification
# 0          <=50K
# 1          <=50K
# 2          <=50K
# 3          <=50K
# 4          <=50K

# %%
mydf5.describe()
# Out:
#                 age  capital-loss  hours-per-week
# count  29536.000000  29536.000000    29536.000000
# mean      38.506094     84.957408       40.243872
# std       13.811739    397.107750       12.326211
# min       17.000000      0.000000        1.000000
# 25%       27.000000      0.000000       40.000000
# 50%       37.000000      0.000000       40.000000
# 75%       48.000000      0.000000       45.000000
# max       90.000000   4356.000000       99.000000

# %%
# 2.5.2. 
# Make sure any value that needs to be replaced with a NAN is set as such. 
# There are at least three ways to do this. One is much easier than the other two.

# %%
# Just for my check
print 'education: ', (mydf5['education']).unique()
print '\nage: ', (mydf5['age']).unique()
print '\ncapital-gain: ', (mydf5['capital-gain']).unique()
print '\nrace: ', (mydf5['race']).unique()
print '\nhours-per-week: ', (mydf5['hours-per-week']).unique()
print '\nsex: ', (mydf5['sex']).unique()
print '\nclassification: ', (mydf5['classification']).unique()
# Out:
# education:  ['Bachelors' 'HS-grad' '11th' 'Masters' '9th' 'Some-college' '7th-8th'
#  'Doctorate' '5th-6th' '10th' '1st-4th' 'Preschool' '12th']
#
# age:  [39 50 38 53 28 37 49 52 31 42 30 23 34 25 32 43 40 54 35 59 56 19 20 45 22
#  48 21 24 57 44 18 47 46 41 29 36 79 27 67 33 76 17 55 61 70 64 71 68 51 58
#  26 60 90 66 65 77 62 63 80 72 74 69 73 81 78 75 82 83 84 85 88 86 87]
#
# capital-gain:  ['2174' '?' '0' '14084' '5178' '5013' '2407' '14344' '15024' '7688' '34095'
#  '4064' '4386' '7298' '1409' '3674' '1055' '3464' '2050' '2176' '594'
#  '6849' '4101' '1111' '3411' '2597' '25236' '4650' '9386' '2463' '3103'
#  '10605' '2964' '3325' '2580' '3471' '4865' '6514' '1471' '2329' '99999'
#  '20051' '2105' '2885' '25124' '10520' '2202' '2961' '27828' '6767' '8614'
#  '2228' '1506' '13550' '2635' '5556' '4787' '3781' '3137' '3818' '3942'
#  '914' '401' '2829' '2977' '4934' '2062' '15020' '1424' '3273' '22040'
#  '4416' '10566' '991' '4931' '1086' '7430' '6497' '114' '7896' '2346'
# ...

# %%
mydf5[ mydf5['capital-gain'] == '?' ]
# Out:
#      education  age capital-gain   race  capital-loss  hours-per-week     sex  \
# 1    Bachelors   50            ?  White             0              13    Male
# 2      HS-grad   38            ?  White             0              40    Male
# 3         11th   53            ?  Black             0              40    Male
# 659    HS-grad   44            ?  White             0              40  Female
#
#     classification
# 1            <=50K
# 2            <=50K
# 3            <=50K
# 659          <=50K

# %%
'''
mydf52 = mydf5[ mydf5['capital-gain'] == '?' ]
mydf52.loc[:,'capital-gain'] = np.nan
mydf52
'''
# Out:
#      education  age  capital-gain   race  capital-loss  hours-per-week  \
# 1    Bachelors   50           NaN  White             0              13
# 2      HS-grad   38           NaN  White             0              40
# 3         11th   53           NaN  Black             0              40
# 659    HS-grad   44           NaN  White             0              40
#
#         sex classification
# 1      Male          <=50K
# 2      Male          <=50K
# 3      Male          <=50K
# 659  Female          <=50K

# %%
mydf5b = mydf5
mydf5b.loc[ mydf5b['capital-gain'] == '?', 'capital-gain'] = np.nan   # <-- !!!! 요거 기억!!!!!!
mydf5b.loc[:20, :]
# Out:
#        education  age capital-gain                race  capital-loss  \
# 0      Bachelors   39         2174               White             0
# 1      Bachelors   50          NaN               White             0
# 2        HS-grad   38          NaN               White             0
# 3           11th   53          NaN               Black             0
# 4      Bachelors   28            0               Black             0
# 5        Masters   37            0               White             0
# 6            9th   49            0               Black             0
# 7        HS-grad   52            0               White             0
# 8        Masters   31        14084               White             0
# 9      Bachelors   42         5178               White             0
# 10  Some-college   37            0               Black             0
# 11     Bachelors   30            0  Asian-Pac-Islander             0
# 12     Bachelors   23            0               White             0
# ...

# %%
# Just for my testing after replacing
mydf5[ mydf5['capital-gain'] == '?' ]
# Out:
# Empty DataFrame
# Columns: [education, age, capital-gain, race, capital-loss, hours-per-week, sex, classification]
# Index: []

# %%
mydf5['capital-gain'] = pd.to_numeric(mydf5['capital-gain'], errors='coerce')  # 'capital-gain'이 numeric 타입이 아니라 conversion 필요
mydf5 = mydf5.fillna(mydf5.mean()['capital-gain'])  # NaN인 부분을 mean()으로 바꾸기. 요 구문 기억해!!!!!!
mydf5.loc[:20, :]
# Out:
#        education  age  capital-gain                race  capital-loss  \
# 0      Bachelors   39   2174.000000               White             0
# 1      Bachelors   50    928.454321               White             0
# 2        HS-grad   38    928.454321               White             0
# 3           11th   53    928.454321               Black             0
# 4      Bachelors   28      0.000000               Black             0
# 5        Masters   37      0.000000               White             0
# 6            9th   49      0.000000               Black             0
# 7        HS-grad   52      0.000000               White             0
# 8        Masters   31  14084.000000               White             0
# 9      Bachelors   42   5178.000000               White             0
# 10  Some-college   37      0.000000               Black             0
# 11     Bachelors   30      0.000000  Asian-Pac-Islander             0
# ...

# %%
# 2.5.3. 
# Look through the dataset and ensure all of your columns have appropriate data types. 
# Numeric columns should be float64 or int64, and textual columns should be object.
mydf5.dtypes
# Out:
# education          object
# age                 int64
# capital-gain      float64
# race               object
# capital-loss        int64
# hours-per-week      int64
# sex                object
# classification     object
# dtype: object

# %%
mydf5.loc[:15, :]
# Out:
#     education  age  capital-gain                race  capital-loss  \
# 0          10   39   2174.000000               White             0
# 1          10   50    928.454321               White             0
# 2           8   38    928.454321               White             0
# 3           6   53    928.454321               Black             0
# 4          10   28      0.000000               Black             0
# 5          11   37      0.000000               White             0
# 6           4   49      0.000000               Black             0
# 7           8   52      0.000000               White             0
# 8          11   31  14084.000000               White             0
# 9          10   42   5178.000000               White             0
# 10          9   37      0.000000               Black             0
# 11         10   30      0.000000  Asian-Pac-Islander             0
# 12         10   23      0.000000               White             0
# ...

# %%
# 2.5.4. Properly encode any ordinal features using the method discussed in the chapter.
ordered_education = ['Preschool','1st-4th', '5th-6th','7th-8th','9th','10th','11th',
                     '12th','HS-grad','Some-college','Bachelors','Masters','Doctorate'  ]
ordered_classification = ['<=50K','>50K']

# %%
mydf5_encoded = mydf5  # mydf5b: encoded one

# !!!!! Remember these codes below !!!!!!!!!
mydf5_encoded['education'] = mydf5_encoded['education'].astype("category", ordered=True, categories=ordered_education ).cat.codes 
mydf5_encoded['classification'] = mydf5_encoded['classification'].astype("category", ordered=True, categories=ordered_classification ).cat.codes

# %%
mydf5_encoded.dtypes
# Out:
# education            int8
# age                 int64
# capital-gain      float64
# race               object
# capital-loss        int64
# hours-per-week      int64
# sex                object
# classification       int8
# dtype: object

# %%
mydf5_encoded.head()
# Out:
#    education  age  capital-gain   race  capital-loss  hours-per-week     sex  \
# 0         10   39   2174.000000  White             0              40    Male
# 1         10   50    928.454321  White             0              13    Male
# 2          8   38    928.454321  White             0              40    Male
# 3          6   53    928.454321  Black             0              40    Male
# 4         10   28      0.000000  Black             0              40  Female
#
#    classification
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %%
# 2.5.5. Properly encode any nominal features by exploding them out into new, separate, boolean features.
mydf5_encoded = pd.get_dummies(mydf5_encoded,columns=['sex','race']) 
mydf5_encoded.loc[:15, :]
# Out:
#     education  age  capital-gain  capital-loss  hours-per-week  \
# 0          10   39   2174.000000             0              40
# 1          10   50    928.454321             0              13
# 2           8   38    928.454321             0              40
# 3           6   53    928.454321             0              40
# 4          10   28      0.000000             0              40
# 5          11   37      0.000000             0              40
# 6           4   49      0.000000             0              16
# 7           8   52      0.000000             0              45
# 8          11   31  14084.000000             0              50
# 9          10   42   5178.000000             0              40
# 10          9   37      0.000000             0              80
# 11         10   30      0.000000             0              40
# 12         10   23      0.000000             0              30
# 13          3   34      0.000000             0              45
# ...

# %%
## Question 2.5.1.
#Before you made any changes to the downloaded dataset, how many of the columns were ordinal?
#[My answer]: 2 ('education', 'classification') <== Correct

# [Explanation];
# Ordinal features are those that are categorical but have an underlaying ordering to them, such as: 
# Tall, Medium, and Small. In this dataset, there are only two ordinal features: education and classification.
# Education is ordinal because people move from one education group to the next based on the amount of their studies. 
# The classification column is ordinal because it's based on how much a person makes. 
# If we had the actual numeric feature of their precise annual income, there is no doubt it would be 
# a continuous column. Since we only know if they make more or less than 50k, it is therefore ordinal.

# While age could be considered 'ordinal', it seems unlikely that the intent is to represent it as a boolean field 
# due to the sheer range of values recorded. Furthermore, for a census, it's more realistic to assume age was 
# documented by year instead of by date simply to ease the already difficult task of data collection. 

# It's unlikely that age is represented as integers as a requirement of the data analysis. 
# If one would like to argue age is ordinal rather than numeric, then they should at least be consistent and 
# also represent 'capital-gain', 'capital-loss', and especially 'hours-per-week' as ordinal as well for the 
# same reasons.

# %%
## Question 2.5.2.
# Before you made any changes to the downloaded dataset, how many of the columns were nominal?
# [My answer]: 2 ('sex', 'race') <== Correct

# [Exmplnation]:
# Race and sex are the only columns that are nominal. Nominal features are those that are categorical, 
# but lack any innate ordering.
